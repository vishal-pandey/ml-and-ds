# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import tensorflow as tf
# Out:
# /anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.7
#   return f(*args, **kwds)

# %%
from bs4 import BeautifulSoup

# %%
import requests as rq

# %%
# car = rq.get("https://www.cardekho.com/used-cars+in+delhi-ncr")
car = rq.get("https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr")

# %%
car.text
# Out:
# '<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head> <link href="https://staticcont.cardekho.com" rel="preconnect" crossorigin="anonymous"><link href="https://stimg.cardekho.com" rel="preconnect" crossorigin="anonymous"><link href="https://connect.facebook.net" rel="preconnect" crossorigin="anonymous"><link href="https://www.googletagmanager.com" rel="preconnect" crossorigin="anonymous"><link href="https://www.google-analytics.com" rel="preconnect" crossorigin="anonymous"><link href="https://www.googletagservices.com" rel="preconnect" crossorigin="anonymous"> <meta charset="utf-8"><title itemprop="name">Used Maruti Celerio in Delhi NCR - 42 Second Hand Cars for Sale (with Offers!)</title><meta name="description" itemprop="description" content="24 Jun 2019 - Currently, 42 Used Maruti Celerio in Delhi NCR are available for sale online. Check out the largest stock of certified, good condition Second Hand Maruti Celerio Cars in all over Delhi NCR, starting at Rs 3.16 Lakh only."><link rel="manifest" href="/manifest.json">   <link rel="canonical" href="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr">   <link rel="amphtml" href="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr?amp=1">     <meta property="og:title" content="Used Maruti Celerio in Delhi NCR - 42 Second Hand Cars for Sale (with Offers!)"><meta property="og:type" content="website"><meta property="og:site_name" content="CarDekho"><meta property="og:image" content="https://stimg.cardekho.com/images/logo/cardekho_logo.jpg"><meta property="og:url" content="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr"><meta property="og:description" content="24 Jun 2019 - Currently, 42 Used Maruti Celerio in Delhi NCR are available for sale online. Check out the largest stock of certified, good condition Second Hand Maruti Celerio Cars in all over Delhi NCR, starting at Rs 3.16 Lakh only."><link rel="preload" href="https://staticcont.cardekho.com/pwa/js/lib/react-16-8.min.js" as="script"><link rel="preload" href="https://staticcont.cardekho.com/pwa/js/lib/react-16-8-dom.min.js" as="script"> <link rel="preload" href="https://staticcont.cardekho.com/pwa/js/bundle/UsedCarListing.2fc3969883d791484e00.js" as="script"> <link rel="preload" href="https://staticcont.cardekho.com/pwa/js/bundle/common.d189af340502b1369185.js" as="script"><link rel="preload" href="https://staticcont.cardekho.com/pwa/js/bundle/bundle.ca2c7e98a9ad0ca269ff.js" as="script"><link rel="prefetch" href="https://staticcont.cardekho.com/pwa/js/bundle/cities.80c434a923034128f199.js"><meta name="theme-color" content="#24272c"><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=5,user-scalable=1">  <link rel="SHORTCUT ICON" href="https://stimg.cardekho.com/pwa/img/cd-favicon-new-16X16.ico" type="image/ico"><meta name="mobile-web-app-capable" content="yes"><meta name="application-name" content="CarDekho">  <meta property="fb:app_id" content="378375538857104"><meta property="fb:pages" content="179167414600"><link href="https://plus.google.com/+cardekho" rel="publisher">  <link rel="alternate" href="android-app://com.girnarsoft.cardekho/used-maruti-celerio+cars+in+delhi-ncr"><link rel="alternate" href="iphone-app://com.girnarsoft.cardekho/used-maruti-celerio+cars+in+delhi-ncr"><meta property="ai:android:url" content="market://details?id=com.girnarsoft.cardekho"><meta property="ai:android:app_name" content="CarDekho"><meta property="ai:android:package" content="com.girnarsoft.cardekho"><meta property="ai:android:url" content="https://www.cardekho.com">  <meta property="ai:android:screen" content="UsedCar">     <link rel="alternate" hreflang="x-default" href="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr">  <link rel="alternate" hreflang="hi" href="https://hindi.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr">  <link rel="alternate" hreflang="ta" href="https://tamil.cardekho.com/used-maruti-celerio+cars+in+de ...

# %%
soup = BeautifulSoup(car.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
#  <head>
#   <link crossorigin="anonymous" href="https://staticcont.cardekho.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://stimg.cardekho.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://connect.facebook.net" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://www.googletagservices.com" rel="preconnect"/>
#   <meta charset="utf-8"/>
#   <title itemprop="name">
#    Used Maruti Celerio in Delhi NCR - 42 Second Hand Cars for Sale (with Offers!)
#   </title>
#   <meta content="24 Jun 2019 - Currently, 42 Used Maruti Celerio in Delhi NCR are available for sale online. Check out the largest stock of certified, good condition Second Hand Maruti Celerio Cars in all over Delhi NCR, starting at Rs 3.16 Lakh only." itemprop="description" name="description"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" rel="canonical"/>
#   <link href="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr?amp=1" rel="amphtml"/>
#   <meta content="Used Maruti Celerio in Delhi NCR - 42 Second Hand Cars for Sale (with Offers!)" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="CarDekho" property="og:site_name"/>
#   <meta content="https://stimg.cardekho.com/images/logo/cardekho_logo.jpg" property="og:image"/>
#   <meta content="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" property="og:url"/>
#   <meta content="24 Jun 2019 - Currently, 42 Used Maruti Celerio in Delhi NCR are available for sale online. Check out the largest stock of certified, good condition Second Hand Maruti Celerio Cars in all over Delhi NCR, starting at Rs 3.16 Lakh only." property="og:description"/>
#   <link as="script" href="https://staticcont.cardekho.com/pwa/js/lib/react-16-8.min.js" rel="preload"/>
#   <link as="script" href="https://staticcont.cardekho.com/pwa/js/lib/react-16-8-dom.min.js" rel="preload"/>
#   <link as="script" href="https://staticcont.cardekho.com/pwa/js/bundle/UsedCarListing.2fc3969883d791484e00.js" rel="preload"/>
#   <link as="script" href="https://staticcont.cardekho.com/pwa/js/bundle/common.d189af340502b1369185.js" rel="preload"/>
#   <link as="script" href="https://staticcont.cardekho.com/pwa/js/bundle/bundle.ca2c7e98a9ad0ca269ff.js" rel="preload"/>
#   <link href="https://staticcont.cardekho.com/pwa/js/bundle/cities.80c434a923034128f199.js" rel="prefetch"/>
#   <meta content="#24272c" name="theme-color"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=5,user-scalable=1" name="viewport"/>
#   <link href="https://stimg.cardekho.com/pwa/img/cd-favicon-new-16X16.ico" rel="SHORTCUT ICON" type="image/ico"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="CarDekho" name="application-name"/>
#   <meta content="378375538857104" property="fb:app_id"/>
#   <meta content="179167414600" property="fb:pages"/>
#   <link href="https://plus.google.com/+cardekho" rel="publisher"/>
#   <link href="android-app://com.girnarsoft.cardekho/used-maruti-celerio+cars+in+delhi-ncr" rel="alternate"/>
#   <link href="iphone-app://com.girnarsoft.cardekho/used-maruti-celerio+cars+in+delhi-ncr" rel="alternate"/>
#   <meta content="market://details?id=com.girnarsoft.cardekho" property="ai:android:url"/>
#   <meta content="CarDekho" property="ai:android:app_name"/>
#   <meta content="com.girnarsoft.cardekho" property="ai:android:package"/>
#   <meta content="https://www.cardekho.com" property="ai:android:url"/>
#   <meta content="UsedCar" property="ai:android:screen"/>
#   <link href="https://www.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" hreflang="x-default" rel="alternate"/>
#   <link href="https://hindi.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" hreflang="hi" rel="alternate"/>
#   <link href="https://tamil.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" hreflang="ta" rel="alternate"/>
#   <link href="https://telugu.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" hreflang="te" rel="alternate"/>
#   <link href="https://malayalam.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" hreflang="ml" rel="alternate"/>
#   <link href="https://kannada.cardekho.com/used-maruti-celerio+cars+in+delhi-ncr" hreflang="kn" rel="alternate"/>
#   <script>
#    var nua=navigator.userAgent,browserDetect={isIos:nua.match(/(iPhone|iPod|iPad)/),isAndroid:nua.match(/Android/),isMobi:nua.match(/Mobi/)};browserDetect.isIos&&document.getElementsByTagName("meta").viewport.setAttribute("content","width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no");var getScript=function(e,t){var i=document.createElement("script");i.async="async",i.src=e,t&&(i.onload=t),document.getElementsByTagName("head")[0].appendChild(i)},idleCb=function(e){return"function"==typeof window.requestIdleCallback?void window.requestIdleCallback(function(){e()}):void e()};"function"==typeof URL&&"function"==typeof Object.assign||idleCb(function(){getScript("\thttps://staticcont.cardekho.com/pwa/js\t/lib/ie-polyfill.js")}),"undefined"==typeof window.IntersectionObserver&&getScript("\thttps://staticcont.cardekho.com/pwa/js\t/lib/IntersectionObserver-polyfill.js")
#   </script>
#   <script>
#    function loadFont(A,t,o){function e(){if(!window.FontFace)return!1;var A=new FontFace("t",'url("...") format("woff2")',{});return A.load(),"loading"===A.status}var n=!window.addEventListener||nua.match(/(Android (2|3|4.0|4.1|4.2|4.3))|(Opera (Mini|Mobi))/)&&!nua.match(/Chrome/);if(!n){var a={};try{a=localStorage||{}}catch(r){}var s="x-font-"+A,c=s+"url",d=s+"css",i=a[c],f=a[d],l=document.createElement("style");if(l.rel="stylesheet",document.head.appendChild(l),!f||i!==t&&i!==o){var u=o&&e()?o:t,m=new XMLHttpRequest;m.open("GET",u),m.onload=function(){m.status>=200&&m.status<400&&(a[c]=u,a[d]=l.textContent=m.responseText)},m.send()}else l.textContent=f}}loadFont("roboto","\thttps://staticcont.cardekho.com/pwa/css\t/roboto_fonts_woff.min.css","\thttps://staticcont.cardekho.com/pwa/css\t/roboto_fonts_woff2.min.css")
#   </script>
#   <style id="criticalcss">
#    @font-face{font-family:cd-fonts;font-display:swap;src:url(https://stimg.cardekho.com/pwa/fonts/cd-fonts87.eot?6ndiib=);src:url(https://stimg.cardekho.com/pwa/fonts/cd-fonts87.eot?6ndiib=#iefix) format("embedded-opentype"),url(https://stimg.cardekho.com/pwa/fonts/cd-fonts87.woff2?6ndiib=) format("woff2"),url(https://stimg.cardekho.com/pwa/fonts/cd-fonts87.woff?6ndiib=) format("woff"),url(https://stimg.cardekho.com/pwa/fonts/cd-fonts87.ttf?6ndiib=) format("truetype"),url(https://stimg.cardekho.com/pwa/fonts/cd-fonts87.svg?6ndiib=#icomoon) format("svg");font-weight:400;font-style:normal}*,:after,:before{-webkit-box-sizing:border-box;box-sizing:border-box}.gsc_container,.gsc_container-fluid{margin-right:auto;margin-left:auto}.gsc_container_hold{padding-left:20px;padding-right:20px}.gsc_col-lg-1,.gsc_col-lg-10,.gsc_col-lg-11,.gsc_col-lg-12,.gsc_col-lg-2,.gsc_col-lg-3,.gsc_col-lg-4,.gsc_col-lg-5,.gsc_col-lg-6,.gsc_col-lg-7,.gsc_col-lg-8,.gsc_col-lg-9,.gsc_col-md-1,.gsc_col-md-10,.gsc_col-md-11,.gsc_col-md-12,.gsc_col-md-2,.gsc_col-md-3,.gsc_col-md-4,.gsc_col-md-5,.gsc_col-md-6,.gsc_col-md-7,.gsc_col-md-8,.gsc_col-md-9,.gsc_col-sm-1,.gsc_col-sm-10,.gsc_col-sm-11,.gsc_col-sm-12,.gsc_col-sm-2,.gsc_col-sm-3,.gsc_col-sm-4,.gsc_col-sm-5,.gsc_col-sm-6,.gsc_col-sm-7,.gsc_col-sm-8,.gsc_col-sm-9,.gsc_col-xs-1,.gsc_col-xs-10,.gsc_col-xs-11,.gsc_col-xs-12,.gsc_col-xs-2,.gsc_col-xs-3,.gsc_col-xs-4,.gsc_col-xs-5,.gsc_col-xs-6,.gsc_col-xs-7,.gsc_col-xs-8,.gsc_col-xs-9{position:relative;min-height:1px}.gsc_col-xs-1,.gsc_col-xs-10,.gsc_col-xs-11,.gsc_col-xs-12,.gsc_col-xs-2,.gsc_col-xs-3,.gsc_col-xs-4,.gsc_col-xs-5,.gsc_col-xs-6,.gsc_col-xs-7,.gsc_col-xs-8,.gsc_col-xs-9{float:left}.gsc_col-xs-12{width:100%}.gsc_col-xs-11{width:91.66666667%}.gsc_col-xs-10{width:83.33333333%}.gsc_col-xs-9{width:75%}.gsc_col-xs-8{width:66.66666667%}.gsc_col-xs-7{width:58.33333333%}.gsc_col-xs-6{width:50%}.gsc_col-xs-5{width:41.66666667%}.gsc_col-xs-4{width:33.33333333%}.gsc_col-xs-3{width:25%}.gsc_col-xs-2{width:16.66666667%}.gsc_col-xs-1{width:8.33333333%}@media only screen and (min-width:768px){.gsc_container_hold{padding:0}.gsc_col-sm-1,.gsc_col-sm-10,.gsc_col-sm-11,.gsc_col-sm-12,.gsc_col-sm-2,.gsc_col-sm-3,.gsc_col-sm-4,.gsc_col-sm-5,.gsc_col-sm-6,.gsc_col-sm-7,.gsc_col-sm-8,.gsc_col-sm-9{float:left}.gsc_col-sm-12{width:100%}.gsc_col-sm-11{width:91.66666667%}.gsc_col-sm-10{width:83.33333333%}.gsc_col-sm-9{width:75%}.gsc_col-sm-8{width:66.66666667%}.gsc_col-sm-7{width:58.33333333%}.gsc_col-sm-6{width:50%}.gsc_col-sm-5{width:41.66666667%}.gsc_col-sm-4{width:33.33333333%}.gsc_col-sm-3{width:25%}.gsc_col-sm-2{width:16.66666667%}.gsc_col-sm-1{width:8.33333333%}}@media only screen and (min-width:992px){.gsc_col-md-1,.gsc_col-md-10,.gsc_col-md-11,.gsc_col-md-12,.gsc_col-md-2,.gsc_col-md-3,.gsc_col-md-4,.gsc_col-md-5,.gsc_col-md-6,.gsc_col-md-7,.gsc_col-md-8,.gsc_col-md-9{float:left}.gsc_col-md-12{width:100%}.gsc_col-md-11{width:91.66666667%}.gsc_col-md-10{width:83.33333333%}.gsc_col-md-9{width:75%}.gsc_col-md-8{width:66.66666667%}.gsc_col-md-7{width:58.33333333%}.gsc_col-md-6{width:50%}.gsc_col-md-5{width:41.66666667%}.gsc_col-md-4{width:33.33333333%}.gsc_col-md-3{width:25%}.gsc_col-md-2{width:16.66666667%}.gsc_col-md-1{width:8.33333333%}}@media only screen and (min-width:1200px){.gsc_col-lg-1,.gsc_col-lg-10,.gsc_col-lg-11,.gsc_col-lg-12,.gsc_col-lg-2,.gsc_col-lg-3,.gsc_col-lg-4,.gsc_col-lg-5,.gsc_col-lg-6,.gsc_col-lg-7,.gsc_col-lg-8,.gsc_col-lg-9{float:left}.gsc_col-lg-12{width:100%}.gsc_col-lg-11{width:91.66666667%}.gsc_col-lg-10{width:83.33333333%}.gsc_col-lg-9{width:75%}.gsc_col-lg-8{width:66.66666667%}.gsc_col-lg-7{width:58.33333333%}.gsc_col-lg-6{width:50%}.gsc_col-lg-5{width:41.66666667%}.gsc_col-lg-4{width:33.33333333%}.gsc_col-lg-3{width:25%}.gsc_col-lg-2{width:16.66666667%}.gsc_col-lg-1{width:8.33333333%}}.clearfix:after,.clearfix:before,.gsc_container-fluid:after,.gsc_container-fluid:before,.gsc_container:after,.gsc_container:before,.gsc_row:after,.gsc_row: ...
#   </style>
#   <script>
#    var notificationPermission = "";
#             try{
#                 if(Notification != undefined){
#                    notificationPermission = Notification.permission;
#                 }
#             }catch(e){}
#
#             dataLayer = [{"page_type":"used-serp.city","compare_car_details":"","source":"web","city":"delhi ncr","state":"","originalLocation":"maruti-celerio+cars+in+delhi-ncr","dynx_itemid":[2322346,2348855,2354196],"dynx_itemid2":[6055,6047,3980],"dynx_pagetype":"searchresults","dynx_event":"dynRmktParamsReady","platform_new":"web","template_Type_new":"used","template_name_new":"used serpcity","city_name_new":"delhi ncr","city_id_new":"0","vehicle_type_new":"car","car_type_new":"used"}];
#
#             if(dataLayer.length){
#
#                 if(dataLayer[0].is_online == "yes"){
#                    dataLayer[0].is_online = navigator.onLine ? "yes" : "no";
#                 }
#                 dataLayer[0].NotificationStatus = notificationPermission;
#                 dataLayer[0].originalLocation = document.location.protocol + '//' +
#                     document.location.hostname +
#                     document.location.pathname +
#                     document.location.search
#             }
#   </script>
#   <script>
#    idleCb(function(){
#
#                     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer', "GTM-P3WXB2");
#                 })
#   </script>
#   <script>
#    window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#             ga('create', "UA-3882094-31", 'auto', {'name': 'myTracker', 'useAmpClientId':true});
#
#             if(dataLayer.length){
#                 ga('myTracker.set', 'dimension1', dataLayer[0].template_name_new);
#                 ga('myTracker.set', 'dimension2', dataLayer[0].brand_new);
#                 ga('myTracker.set', 'dimension3', dataLayer[0].model_new);
#                 ga('myTracker.set', 'dimension4', dataLayer[0].variant_new);
#                 ga('myTracker.set', 'dimension5', dataLayer[0].body_type_new);
#                 ga('myTracker.set', 'contentGroup4', dataLayer[0].template_name_new);
#             }
#
#             ga('myTracker.send', 'pageview');
#             idleCb(function(){
#                 getScript('https://www.google-analytics.com/analytics.js');
#             })
#   </script>
#   <noscript id="deferred-styles">
#   </noscript>
#   <script>
#    var prevStyle="",loadStyles=function(e){var t=document.getElementById("deferred-styles"),r=window.outerWidth?window.outerWidth:window.innerWidth;r<767?"mobile"!==prevStyle&&(t.innerHTML='<link rel="stylesheet"  href="\thttps://staticcont.cardekho.com/pwa/css\t/\tmobile-dd9d9aab.css\t">',prevStyle="mobile"):("main"!==prevStyle&&(t.innerHTML='<link rel="stylesheet"  href="\thttps://staticcont.cardekho.com/pwa/css\t/\tmain-7893325a.css\t">'),prevStyle="main")};loadStyles()
#   </script>
#   <script>
#    document.addEventListener("gesturestart",function(e){e.preventDefault()});var loadDeferredStyles=function(){var e=document.getElementById("deferred-styles");if(null!==e){var t=document.createElement("div");t.id="deferred-styles",t.innerHTML=e.textContent,document.body.appendChild(t),e.parentElement.removeChild(e)}},raf=window.requestAnimationFrame||window.mozRequestAnimationFrame||window.webkitRequestAnimationFrame||window.msRequestAnimationFrame||window.oRequestAnimationFrame;raf?raf(function(){window.setTimeout(loadDeferredStyles,0)}):window.addEventListener("load",loadDeferredStyles),window.addEventListener("orientationchange",loadStyles)
#   </script>
#   <script>
#    var googletag=googletag||{};googletag.cmd=googletag.cmd||[]
#   </script>
#   <script>
#    idleCb(function(){getScript("https://www.googletagservices.com/tag/js/gpt.js"),getScript("\thttps://staticcont.cardekho.com/pwa/js\t/\tbundle\t/\tad-commonscript-53dd8fb0.js\t")})
#   </script>
#  </head>
#  <body class="Language">
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P3WXB2" style="display:none;visibility:hidden" width="0">
#    </iframe>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WG2J6S" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div id="fb-root">
#   </div>
#   <div id="main">
#    <div class="desktop" data-reactroot="" id="rf01">
#     <header class="header" data-gssticky="1" data-track-component="Header">
#      <div class="topArea">
#       <div class="gsc_container">
#        <div class="gsc_row">
#         <div class="logo gsc_col-sm-3">
#          <a href="/" title="CarDekho.com - Best place to buy New and Used Cars in India">
#           <img alt="CarDekho.com - Best place to buy New and Used Cars in India" src="https://stimg.cardekho.com/pwa/img/CarDekho-Logo.svg"/>
#          </a>
#         </div>
#         <div class="searchArea gsc_col-sm-5 ">
#          <div class="container">
#           <div data-track-component="SearchBox">
#            <form action="/searchresult" data-track-section="menu_bar" data-type="searchformall">
#             <span class="backArrow">
#              <span data-arrow-left="true">
#              </span>
#             </span>
#             <div class="ReactTypeahead inputfield gs_ta " data-gsmtl-container="true">
#              <input aria-label="Select City" autocomplete="new-password" class="" data-gsf-name="q" data-gsv-min-length="50" data-gsv-type="required" data-id="cardekhosearchtext" data-move-top="0" data-type="q" id="cardekhosearchtext" maxlength="50" name="q50cf36757d607" placeholder="Search Cars or Brands eg. Swift, or Maruti" type="text" value=""/>
#              <label class=" " for="cardekhosearchtext">
#              </label>
#             </div>
#             <button class="searchbtn" type="submit" value="search">
#              <i>
#              </i>
#             </button>
#             <div id="searchlistheader">
#             </div>
#            </form>
#           </div>
#          </div>
#         </div>
#         <div class="gsc_col-sm-4 loginBtn">
#          <ul>
#           <li class="hidden-sm hidden-md">
#            <span>
#             Feedback
#            </span>
#           </li>
#           <li data-track-section="headertop">
#            <span class="languagedropdown customSelect">
#             <select>
#              <option data-lang="English" data-value="https://www.cardekho.com" value="en">
#               English
#              </option>
#              <option data-lang="Hindi" data-value="https://hindi.cardekho.com" value="hi">
#               हिन्दी
#              </option>
#              <option data-lang="Tamil" data-value="https://tamil.cardekho.com" value="ta">
#               தமிழ்
#              </option>
#              <option data-lang="Telugu" data-value="https://telugu.cardekho.com" value="te">
#               తెలుగు
#              </option>
#              <option data-lang="Malayalam" data-value="https://malayalam.cardekho.com" value="ml">
#               മലയാളം
#              </option>
#              <option data-lang="Kannada" data-value="https://kannada.cardekho.com" value="kn">
#               ಕನ್ನಡ
#              </option>
#             </select>
#            </span>
#           </li>
#           <li>
#            <i class="userIcon icon-cd_my-account">
#            </i>
#            <span class="username">
#             Login / Register
#            </span>
#            <i data-icon-arrow-bottom="withoutfill">
#            </i>
#            <div class="showuserInfo">
#             <div class="myaccountdropdown ">
#              <div class="myaccount" data-track-section="myaccount">
#               <ul>
#                <li>
#                 <span class="login">
#                  Login / Register
#                 </span>
#                </li>
#                <li>
#                 <a href="/info/contact_us" title="Contact Us ">
#                  Contact Us
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="bottomArea">
#       <div class="gsc_container">
#        <div class="gsc_row">
#         <nav class="gsc_col-sm-12 gsc_col-md-12">
#          <ul class="" data-track-section="MainMenu">
#           <li class=" mainMenu " data-slug="/newcars">
#            <a href="/newcars" title="New Car">
#             <span class="innerSpan">
#              NEW CAR
#              <i>
#              </i>
#             </span>
#            </a>
#            <ul class="subMenu" data-track-section="SubMenu">
#             <li class=" " data-slug="/newcars">
#              <span>
#               <span class="innerSpan">
#                Search New Cars
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/latestcars">
#              <a href="/latestcars" title="Latest Cars">
#               <span class="innerSpan">
#                Latest Cars
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/mostpopularcars">
#              <a href="/mostpopularcars" title="Popular Cars">
#               <span class="innerSpan">
#                Popular Cars
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/upcomingcars">
#              <a href="/upcomingcars" title="Upcoming Cars">
#               <span class="innerSpan">
#                Upcoming Cars
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/car-deals-discount-offers.htm">
#              <a href="/car-deals-discount-offers.htm" title="Offers and Discount">
#               <span class="innerSpan">
#                Offers and Discount
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/car-service-center.htm">
#              <a href="/car-service-center.htm" title="Service Centers">
#               <span class="innerSpan">
#                Service Centers
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/cardealers">
#              <a href="/cardealers" title="Dealers">
#               <span class="innerSpan">
#                Dealers
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/winners-list.htm">
#              <span rel="noopener">
#               <span class="innerSpan">
#                Win iPhone
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="http://bit.ly/2HKnvtS">
#              <span rel="noopener">
#               <span class="innerSpan">
#                MG Hector
#                <span class="sponsoredmenu">
#                 <p>
#                  Ad
#                 </p>
#                </span>
#               </span>
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li class=" mainMenu " data-slug="/used-cars+in+new-delhi">
#            <span class="used-cars-india">
#             <span class="innerSpan">
#              USED CAR
#              <i>
#              </i>
#             </span>
#            </span>
#            <ul class="subMenu" data-track-section="SubMenu">
#             <li class=" mainMenu " data-slug="#">
#              <a href="#" title="Cars In Your City">
#               <span class="innerSpan">
#                Cars In Your City
#                <i>
#                </i>
#               </span>
#              </a>
#              <ul class="subMenuDeep" data-track-section="SubMenu">
#               <li class=" " data-slug="/used-cars+in+ahmedabad">
#                <a href="/used-cars+in+ahmedabad" title="Used Cars In Ahmedabad">
#                 <span class="innerSpan">
#                  Ahmedabad
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+bangalore">
#                <a href="/used-cars+in+bangalore" title="Used Cars In Bangalore">
#                 <span class="innerSpan">
#                  Bangalore
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+chennai">
#                <a href="/used-cars+in+chennai" title="Used Cars In Chennai">
#                 <span class="innerSpan">
#                  Chennai
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+delhi-ncr">
#                <a href="/used-cars+in+delhi-ncr" title="Used Cars In Delhi NCR">
#                 <span class="innerSpan">
#                  Delhi NCR
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+hyderabad">
#                <a href="/used-cars+in+hyderabad" title="Used Cars In Hyderabad">
#                 <span class="innerSpan">
#                  Hyderabad
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+jaipur">
#                <a href="/used-cars+in+jaipur" title="Used Cars In Jaipur">
#                 <span class="innerSpan">
#                  Jaipur
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+kolkata">
#                <a href="/used-cars+in+kolkata" title="Used Cars In Kolkata">
#                 <span class="innerSpan">
#                  Kolkata
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+mumbai">
#                <a href="/used-cars+in+mumbai" title="Used Cars In Mumbai">
#                 <span class="innerSpan">
#                  Mumbai
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+pune">
#                <a href="/used-cars+in+pune" title="Used Cars In Pune">
#                 <span class="innerSpan">
#                  Pune
#                 </span>
#                </a>
#               </li>
#               <li class=" " data-slug="/used-cars+in+india">
#                <a href="/used-cars+in+india" title="Used Cars In More Cities">
#                 <span class="innerSpan">
#                  More Cities
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class=" " data-slug="/usedCars">
#              <a href="/usedCars" title="Search Used Cars">
#               <span class="innerSpan">
#                Search Used Cars
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/sell-used-car">
#              <span>
#               <span class="innerSpan">
#                Sell Used Cars
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/used-car-valuation.htm">
#              <a href="/used-car-valuation.htm" title="Used Car Valuation">
#               <span class="innerSpan">
#                Used Car Valuation
#               </span>
#              </a>
#             </li>
#             <li class=" new hidden-sm" data-slug="/used-car-dealer-showroom.htm">
#              <span>
#               <span class="innerSpan">
#                Used Car Dealers
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/userlogin.htm?source=pwa">
#              <span>
#               <span class="innerSpan">
#                My Listing
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/trustmark/index.html">
#              <span>
#               <span class="innerSpan">
#                CarDekho Trustmark Dealers
#               </span>
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li class=" " data-slug="/sell-used-car">
#            <a href="/sell-used-car" title="Sell Car">
#             <span class="innerSpan">
#              SELL CAR
#             </span>
#            </a>
#           </li>
#           <li class=" " data-slug="/compare-cars">
#            <a href="/compare-cars" title="Compare Cars">
#             <span class="innerSpan">
#              COMPARE CARS
#             </span>
#            </a>
#           </li>
#           <li class=" mainMenu " data-slug="/india-car-news.htm">
#            <a href="/india-car-news.htm" title="News &amp; Reviews Cars">
#             <span class="innerSpan">
#              NEWS &amp; REVIEWS
#              <i>
#              </i>
#             </span>
#            </a>
#            <ul class="subMenu" data-track-section="SubMenu">
#             <li class=" " data-slug="/india-car-news.htm">
#              <a href="/india-car-news.htm" title="Car News">
#               <span class="innerSpan">
#                Car News
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/features-stories.htm">
#              <span>
#               <span class="innerSpan">
#                Feature Stories
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/car-reviews.htm">
#              <a href="/car-reviews.htm" title="User Reviews">
#               <span class="innerSpan">
#                User Reviews
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/road-test.htm">
#              <a href="/road-test.htm" title="Road Test">
#               <span class="innerSpan">
#                Road Test
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="/car-videos.htm">
#              <a href="/car-videos.htm" title="Video Reviews">
#               <span class="innerSpan">
#                Video Reviews
#               </span>
#              </a>
#             </li>
#             <li class=" new" data-slug="/write-car-user-review.html">
#              <span>
#               <span class="innerSpan">
#                Write a Review
#               </span>
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li class=" mainMenu " data-slug="#">
#            <span>
#             <span class="innerSpan">
#              MORE
#              <i>
#              </i>
#             </span>
#            </span>
#            <ul class="subMenu" data-track-section="SubMenu">
#             <li class=" " data-slug="/car-loan/">
#              <div class=" buttonHolder">
#               <span class=" ">
#                <!-- -->
#                Car Loan
#               </span>
#              </div>
#             </li>
#             <li class=" " data-slug="/car-loan-emi-calculator.htm">
#              <a href="/car-loan-emi-calculator.htm" title="EMI Calculator">
#               <span class="innerSpan">
#                EMI Calculator
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="https://tyres.cardekho.com/?utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Moretab_PrimaryNav">
#              <span>
#               <span class="innerSpan">
#                Car Tyres
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/questionanswer/latestquestions">
#              <span>
#               <span class="innerSpan">
#                Ask A Question
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="/new-car-deals-in-new-delhi.htm">
#              <a href="/new-car-deals-in-new-delhi.htm" title="Car Dealz">
#               <span class="innerSpan">
#                Car Dealz
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class=" mainMenu new hidden-sm" data-slug="#">
#            <span>
#             <span class="innerSpan">
#              Cardekho Ventures
#              <i>
#              </i>
#             </span>
#            </span>
#            <ul class="subMenu" data-track-section="SubMenu">
#             <li class=" " data-slug="https://www.gaadi.com/?utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header">
#              <span rel="noopener" target="_blank">
#               <span class="innerSpan">
#                <span class="icon-carDekhoLogo BrandingLg">
#                </span>
#                Gaadi Stores
#               </span>
#              </span>
#             </li>
#             <li class=" " data-slug="https://www.insurancedekho.com/car-insurance/?track=carinsurance&amp;utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header">
#              <a href="https://www.insurancedekho.com/car-insurance/?track=carinsurance&amp;utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header" rel="noopener" target="_blank" title="Car Insurance">
#               <span class="innerSpan">
#                <span class="icon-insurancelogo BrandingLg">
#                </span>
#                Car Insurance
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="https://www.insurancedekho.com/health-insurance/?utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header">
#              <a href="https://www.insurancedekho.com/health-insurance/?utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header" rel="noopener" target="_blank" title="Health Insurance">
#               <span class="innerSpan">
#                <span class="icon-insurancelogo BrandingLg">
#                </span>
#                Health Insurance
#               </span>
#              </a>
#             </li>
#             <li class=" " data-slug="https://ucl.cardekho.com/loan-offers/?utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header">
#              <a href="https://ucl.cardekho.com/loan-offers/?utm_source=cardekho&amp;utm_medium=internal&amp;utm_campaign=Menu_Header" rel="noopener" target="_blank" title="Loan Against Car">
#               <span class="innerSpan">
#                <span class="icon-carDekhoLogo BrandingLg">
#                </span>
#                Loan Against Car
#               </span>
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#          <span class="linkArea">
#           <i class="icon-cd-locationPin">
#           </i>
#           <span data-selectcity="true">
#            Select City
#           </span>
#           <i data-icon-arrow-bottom="withoutfill">
#           </i>
#          </span>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="app-content">
#      <div class="uc-main">
#       <aside class="adHolderTop hidden-xs hidden-sm">
#        <p>
#         Ad
#        </p>
#        <div data-load-initially="false" data-sdef="/1089059/CarDekho_UsedCarFilter_970x90_ATF_n" data-slot-def="/1089059/CarDekho_UsedCarFilter_970x90_ATF_n" data-type="banner" id="div-gpt-ad-1409818526285-21">
#        </div>
#       </aside>
#       <div class="subheader_sticky">
#        <div class="recentlyViewMain hidden-lg hidden-md" data-sub-header="true">
#         <div class="usedCarCityBox">
#          <div class="searchRightbox">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="gsc_container gsc_container_hold breadcrumb " data-track-component="Breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#        <span class="" data-tag="" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a href="/" itemprop="item" title="Home">
#          <span itemprop="name">
#           Home
#          </span>
#         </a>
#         <meta content="1" itemprop="position"/>
#        </span>
#        <span class="" data-tag="" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a href="/usedCars" itemprop="item" title="Used Cars">
#          <span itemprop="name">
#           Used Cars
#          </span>
#         </a>
#         <meta content="2" itemprop="position"/>
#        </span>
#        <span class="" data-tag="">
#         <span>
#          Delhi NCR
#         </span>
#        </span>
#       </div>
#       <main class="gsc_container UsedCarListing">
#        <div class="gsc_row">
#         <div class="gsc_col-xs-12 gsc_col-sm-12 gsc_col-md-8 gsc_col-lg-9 float-right">
#          <div class="gsc_row gsc_container_hold" data-track-component="Usedcarfilter">
#           <div class="gsc_col-md-6 gsc_col-lg-8 gsc_col-sm-12 gsc_col-xs-12">
#            <span class="count">
#             42
#            </span>
#            <h1 class="truncate">
#             Used Maruti Celerio in Delhi NCR
#            </h1>
#           </div>
#           <div class="gsc_col-md-6 gsc_col-lg-4 gsc_col-sm-6 gsc_col-xs-12 sortBy hidden-xs hidden-sm" data-gsf-name="sortbyName" data-track-section="Sortby">
#            <div class="ReactTypeahead inputfield gs_ta smallInput" data-gsmtl-container="true">
#             <input aria-label="Select City" autocomplete="new-password" class="" data-gsf-name="sortbyName" data-gsv-min-length="50" data-gsv-type="required" data-id="sortbyName" data-move-top="0" data-type="sortbyName" id="sortbyName" maxlength="50" name="sortbyNamefabc3cd66a4a8" readonly="" type="text" value=""/>
#             <label class=" " for="sortbyName">
#              Sort by :
#             </label>
#            </div>
#            <div class="viewTypeWrap">
#             <span class="viewType active">
#              <i class="icon-cd-grid_icon">
#              </i>
#             </span>
#             <span class="viewType ">
#              <i class="icon-cd-listing_view">
#              </i>
#             </span>
#            </div>
#           </div>
#           <div class="gsc_col-md-12 gsc_col-sm-12 gsc_col-xs-12 sortedItem">
#            <div class="mobileCarousel">
#             <ul class="gsc_main">
#              <li class="crosschips">
#               Maruti Celerio
#               <span value="Maruti Celerio">
#                ×
#               </span>
#              </li>
#              <li class="clearall">
#               <span class="linkBlack hover">
#                Clear All Filters
#               </span>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="listitems">
#           <div class="gsc_row gsc_container_hold" data-track-component="Used Car Listing">
#            <div class="gsc_col-xs-12">
#            </div>
#            <div class=" reportAd gsc_col-lg-4 gsc_col-md-6 gsc_col-sm-6 gsc_col-xs-12 append_list">
#             <div class="card card_used shadowWPadding " data-img-fit="true">
#              <div class="gsc_col-sm-12 gsc_col-md-12 imgTopRound paddingnone hover BgBlurImg">
#               <div class="ribbon">
#                <span class="icon-star-full-fill">
#                </span>
#               </div>
#               <img alt="2015 Maruti Celerio CNG VXI MT" class="hover imageTransition" data-lazy="true" src="https://stimg.cardekho.com/pwa/img/spacer3x2.png" title="2015 Maruti Celerio CNG VXI MT"/>
#              </div>
#              <div class="gsc_col-sm-12 gsc_col-md-12 holder">
#               <div class="title">
#                <a href="/used-car-details/used-Maruti-Celerio-CNG-VXI-MT-cars-Gurgaon_A4DD17E617CBC3F8CD796BD4D3409D97.htm" title="2015 Maruti Celerio CNG VXI MT">
#                 2015 Maruti Celerio CNG VXI MT
#                </a>
#               </div>
#               <div class="otherlinks">
#                <i>
#                </i>
#                <div class="otherLinkBox hide">
#                 <ul>
#                  <li class="hover">
#                   <span class="icon-report">
#                   </span>
#                   Report Ad
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="price">
#                <span class="icon-cd_R">
#                 Rs.
#                </span>
#                3.8 Lakh
#               </div>
#               <div class="caption hover ">
#                <span class="truncate" title="Gurgaon">
#                 Gurgaon
#                </span>
#                <span class="" title="11 photos">
#                 11
#                 <!-- -->
#                 photos
#                </span>
#               </div>
#               <div class="dotlist">
#                <span>
#                 64,687
#                 <!-- -->
#                 km
#                </span>
#                <span>
#                 CNG
#                </span>
#                <span class=" ">
#                 Gurgaon
#                </span>
#               </div>
#               <div class="buttonHolder" data-track-component="Usedcarshortlist">
#                <button class="primaryButton" type="button">
#                 View Seller Details
#                </button>
#                <span class=" heartLink icon-cd-heart_empty" title="Maruti Celerio CNG VXI MT">
#                </span>
#                <span class="whatsapp">
#                 <i class="icon-whatsapp">
#                 </i>
#                 Chat
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class=" reportAd gsc_col-lg-4 gsc_col-md-6 gsc_col-sm-6 gsc_col-xs-12 append_list">
#             <div class="card card_used shadowWPadding " data-img-fit="true">
#              <div class="gsc_col-sm-12 gsc_col-md-12 imgTopRound paddingnone hover BgBlurImg">
#               <img alt="2018 Maruti Celerio VXI MT" class="hover imageTransition" data-lazy="true" src="https://stimg.cardekho.com/pwa/img/spacer3x2.png" title="2018 Maruti Celerio VXI MT"/>
#              </div>
#              <div class="gsc_col-sm-12 gsc_col-md-12 holder">
#               <div class="title">
#                <a href="/used-car-details/used-Maruti-Celerio-VXI-MT-cars-Noida_F52D80F8CE838DDC5A4369026229B812.htm" title="2018 Maruti Celerio VXI MT">
#                 2018 Maruti Celerio VXI MT
#                </a>
#               </div>
#               <div class="otherlinks">
#                <i>
#                </i>
#                <div class="otherLinkBox hide">
#                 <ul>
#                  <li class="hover">
#                   <span class="icon-report">
#                   </span>
#                   Report Ad
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="price">
#                <span class="icon-cd_R">
#                 Rs.
#                </span>
#                4.95 Lakh
#               </div>
#               <div class="caption hover ">
#                <span class="truncate" title="Sector 10">
#                 Sector 10
#                </span>
#                <span class="" title="6 photos">
#                 6
#                 <!-- -->
#                 photos
#                </span>
#               </div>
#               <div class="dotlist">
#                <span>
#                 12,319
#                 <!-- -->
#                 km
#                </span>
#                <span>
#                 Petrol
#                </span>
#                <span class=" ">
#                 Noida
#                </span>
#               </div>
#               <div class="buttonHolder" data-track-component="Usedcarshortlist">
#                <button class="primaryButton" type="button">
#                 View Seller Details
#                </button>
#                <span class=" heartLink icon-cd-heart_empty" title="Maruti Celerio VXI MT">
#                </span>
#                <span class="whatsapp">
#                 <i class="icon-whatsapp">
#                 </i>
#                 Chat
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class=" reportAd gsc_col-lg-4 gsc_col-md-6 gsc_col-sm-6 gsc_col-xs-12 append_list">
#             <div class="card card_used shadowWPadding " data-img-fit="true">
#              <div class="gsc_col-sm-12 gsc_col-md-12 imgTopRound paddingnone hover BgBlurImg">
#               <img alt="2014 Maruti Celerio ZXI" class="hover imageTransition" data-lazy="true" src="https://stimg.cardekho.com/pwa/img/spacer3x2.png" title="2014 Maruti Celerio ZXI"/>
#              </div>
#              <div class="gsc_col-sm-12 gsc_col-md-12 holder">
#               <div class="title">
#                <a href="/used-car-details/used-Maruti-Celerio-2014-2017-ZXI-cars-Noida_07F870858B1A86CC4C06D67DD16DCD1D.htm" title="2014 Maruti Celerio ZXI">
#                 2014 Maruti Celerio ZXI
#                </a>
#               </div>
#               <div class="otherlinks">
#                <i>
#                </i>
#                <div class="otherLinkBox hide">
#                 <ul>
#                  <li class="hover">
#                   <span class="icon-report">
#                   </span>
#                   Report Ad
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="price">
#                <span class="icon-cd_R">
#                 Rs.
#                </span>
#                3.7 Lakh
#               </div>
#               <div class="caption hover ">
#                <span class="truncate" title="Sector 10">
#                 Sector 10
#                </span>
#                <span class="" title="8 photos">
#                 8
#                 <!-- -->
#                 photos
#                </span>
#               </div>
#               <div class="dotlist">
#                <span>
#                 52,000
#                 <!-- -->
#                 km
#                </span>
#                <span>
#                 Petrol
#                </span>
#                <span class=" ">
#                 Noida
#                </span>
#               </div>
#               <div class="buttonHolder" data-track-component="Usedcarshortlist">
#                <button class="primaryButton" type="button">
#                 View Seller Details
#                </button>
#                <span class=" heartLink icon-cd-heart_empty" title="Maruti Celerio ZXI">
#                </span>
#                <span class="whatsapp">
#                 <i class="icon-whatsapp">
#                 </i>
#                 Chat
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class=" reportAd gsc_col-lg-4 gsc_col-md-6 gsc_col-sm-6 gsc_col-xs-12 append_list">
#             <div class="card card_used shadowWPadding " data-img-fit="true">
#              <div class="gsc_col-sm-12 gsc_col-md-12 imgTopRound paddingnone hover BgBlurImg">
#               <img alt="2014 Maruti Celerio VXI" class="hover imageTransition" data-lazy="true" src="https://stimg.cardekho.com/pwa/img/spacer3x2.png" title="2014 Maruti Celerio VXI"/>
#              </div>
#              <div class="gsc_col-sm-12 gsc_col-md-12 holder">
#               <div class="title">
#                <a href="/used-car-details/used-Maruti-Celerio-2014-2017-VXI-cars-New-Delhi_0DBC325C11C2AA30C9F9A0AED004EB91.htm" title="2014 Maruti Celerio VXI">
#                 2014 Maruti Celerio VXI
#                </a>
#               </div>
#               <div class="otherlinks">
#                <i>
#                </i>
#                <div class="otherLinkBox hide">
#                 <ul>
#                  <li class="hover">
#                   <span class="icon-report">
#                   </span>
#                   Report Ad
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="price">
#                <span class="icon-cd_R">
#                 Rs.
#                </span>
#                3.2 Lakh
#               </div>
#               <div class="caption hover ">
#                <span class="truncate" title="Lajpat Nagar">
#                 Lajpat Nagar
#                </span>
#                <span class="" title="7 photos">
#                 7
#                 <!-- -->
#                 photos
#                </span>
#               </div>
#               <div class="dotlist">
#                <span>
#                 48,300
#                 <!-- -->
#                 km
#                </span>
#                <span>
#                 Petrol
#                </span>
#                <span class=" ">
#                 New Delhi
#                </span>
#               </div>
#               <div class="buttonHolder" data-track-component="Usedcarshortlist">
#                <button class="primaryButton" type="button">
#                 View Seller Details
#                </button>
#                <span class=" heartLink icon-cd-heart_empty" title="Maruti Celerio VXI">
#                </span>
#                <span class="whatsapp">
#                 <i class="icon-whatsapp">
#                 </i>
#                 Chat
#                </span>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class=" reportAd gsc_col-lg-4 gsc_col-md-6 gsc_col-sm-6 gsc_col-xs-12 append_list">
#             <div class="card card_used shadowWPadding " data-img-fit="true">
#              <div class="gsc_col-sm-12 gsc_col-md-12 imgTopRound paddingnone hover BgBlurImg">
#               <img alt="2015 Maruti Celerio VXI AT" class="hover imageTransition" data-lazy="true" src="https://stimg.cardekho.com/pwa/img/spacer3x2.png" title="2015 Maruti Celerio VXI AT"/>
#              </div>
#              <div class="gsc_col-sm-12 gsc_col-md-12 holder">
#               <div class="title">
#                <a href="/used-car-details/used-Maruti-Celerio-2014-2017-VXI-AT-cars-Faridabad_8CF1DBF869F04F23D084110D2EC8BE3B.htm" title="2015 Maruti Celerio VXI AT">
#                 2015 Maruti Celerio VXI AT
#                </a>
#               </div>
#               <div class="otherlinks">
#                <i>
#                </i>
#                <div class="otherLinkBox hide">
#                 <ul>
#                  <li class="hover">
#                   <span class="icon-report">
#                   </span>
#                   Report Ad
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="price">
#                <span class="icon-cd_R">
#                 Rs.
#                </span>
#                3.9 Lakh
#               </div>
# ...
#                 Individual
#                 <span>
#                  (
#                  <!-- -->
#                  7
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="gs_control__indicator">
#                 </span>
#                </label>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="borderBottom ">
#             <h3>
#              Transmission
#              <span class="icon-addition">
#              </span>
#             </h3>
#             <div class="content " data-default="off" data-gsp-accordion-content="" style="height:0px">
#              <ul class="checkBoxWrap Transmission" data-track-section="Search by transmission">
#               <li>
#                <label class="gs_control gs_checkbox" title="Automatic">
#                 <input data-checked="false" name="Transmission" title="Automatic" type="checkbox" value="Automatic"/>
#                 Automatic
#                 <span>
#                  (
#                  <!-- -->
#                  22
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="gs_control__indicator">
#                 </span>
#                </label>
#               </li>
#               <li>
#                <label class="gs_control gs_checkbox" title="Manual">
#                 <input data-checked="false" name="Transmission" title="Manual" type="checkbox" value="Manual"/>
#                 Manual
#                 <span>
#                  (
#                  <!-- -->
#                  20
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="gs_control__indicator">
#                 </span>
#                </label>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="borderBottom ">
#             <h3>
#              Colors
#              <span class="icon-addition">
#              </span>
#             </h3>
#             <div class="content colorFilter " data-default="off" data-gsp-accordion-content="" style="height:0px">
#              <ul class="checkBoxWrap colors" data-track-section="Search by colors">
#               <li>
#                <label class="gs_control gs_checkbox" title="White">
#                 <input data-checked="false" name="colors" title="White" type="checkbox" value="White"/>
#                 White
#                 <span>
#                  (
#                  <!-- -->
#                  17
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="colorHolder">
#                  <i class="whiteIcon">
#                  </i>
#                 </span>
#                </label>
#               </li>
#               <li>
#                <label class="gs_control gs_checkbox" title="Silver">
#                 <input data-checked="false" name="colors" title="Silver" type="checkbox" value="Silver"/>
#                 Silver
#                 <span>
#                  (
#                  <!-- -->
#                  9
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="colorHolder">
#                  <i class="silverIcon">
#                  </i>
#                 </span>
#                </label>
#               </li>
#               <li>
#                <label class="gs_control gs_checkbox" title="Red">
#                 <input data-checked="false" name="colors" title="Red" type="checkbox" value="Red"/>
#                 Red
#                 <span>
#                  (
#                  <!-- -->
#                  3
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="colorHolder">
#                  <i class="redIcon">
#                  </i>
#                 </span>
#                </label>
#               </li>
#               <li>
#                <label class="gs_control gs_checkbox" title="Gray">
#                 <input data-checked="false" name="colors" title="Gray" type="checkbox" value="Gray"/>
#                 Gray
#                 <span>
#                  (
#                  <!-- -->
#                  2
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="colorHolder">
#                  <i class="grayIcon">
#                  </i>
#                 </span>
#                </label>
#               </li>
#               <li>
#                <label class="gs_control gs_checkbox" title="Blue">
#                 <input data-checked="false" name="colors" title="Blue" type="checkbox" value="Blue"/>
#                 Blue
#                 <span>
#                  (
#                  <!-- -->
#                  1
#                  <!-- -->
#                  )
#                 </span>
#                 <span class="colorHolder">
#                  <i class="blueIcon">
#                  </i>
#                 </span>
#                </label>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="filter filterOpt carsWithImage" data-track-section="Cars With Photos">
#             <label class="gs_control gs_checkbox" title="Cars with photos">
#              <input data-checked="false" name="carsWithImage" title="carsWithPhotos" type="checkbox" value="with-photos"/>
#              <span class="photos">
#               <i class="photosicon" data-lazy="true" data-lazy-cls="bodytypesprite">
#               </i>
#               Cars with photos
#              </span>
#              <span class="gs_control__indicator">
#              </span>
#             </label>
#            </div>
#           </div>
#           <div id="overlaybg2">
#           </div>
#          </div>
#         </div>
#         <ul class="filterSticky hidden-lg hidden-md" data-track-component="stickyfilter">
#          <li>
#           <span class="icon-cd-sorting">
#           </span>
#           Sort
#          </li>
#          <li>
#           <span class="icon-cd-filter" data-openfilter="true">
#           </span>
#           <span class="count hide">
#            0
#           </span>
#           Filters
#          </li>
#          <li>
#           <span class="icon-cd-listing_view">
#           </span>
#          </li>
#         </ul>
#         <div>
#          <div class="sortByPanel hidden-lg hidden-md hidden-sm hidden-xs" data-track-component="Usedcarfilter">
#           <div class="heading">
#            Sort By
#           </div>
#           <div class="gsc_closeBtn">
#            ×
#           </div>
#           <ul class="clear" data-track-section="Sortby">
#            <li>
#             <div class="listTitle">
#              Price
#             </div>
#             <div class="listText">
#              <div class="" data-sort="true" data-sortby="price" data-sortorder="asc">
#               Low to High
#              </div>
#              <div class="" data-sort="true" data-sortby="price" data-sortorder="desc">
#               High to Low
#              </div>
#             </div>
#            </li>
#            <li>
#             <div class="listTitle">
#              Kilometers Driven
#             </div>
#             <div class="listText">
#              <div class="" data-sort="true" data-sortby="kms_run" data-sortorder="asc">
#               Low to High
#              </div>
#             </div>
#            </li>
#            <li>
#             <div class="listTitle">
#              Model Year
#             </div>
#             <div class="listText">
#              <div class="" data-sort="true" data-sortby="registration_year" data-sortorder="desc">
#               New to Old
#              </div>
#             </div>
#            </li>
#            <li>
#             <div class="listTitle">
#              Relevance
#             </div>
#             <div class="listText">
#              <div class="" data-sort="true" data-sortby="" data-sortorder="">
#               Default
#              </div>
#             </div>
#            </li>
#           </ul>
#          </div>
#          <div class="sortByOverlay">
#          </div>
#         </div>
#        </div>
#        <div>
#         <section class="recentlyViewMain" data-id="compare-popup" data-track-component="Shortlisted">
#          <div class="recently_overlay">
#          </div>
#          <div class="recentView shortList hide">
#           <div class="gsc_closeBtn">
#            ×
#           </div>
#           <div class="shortviewtitle">
#            Shortlisted
#           </div>
#           <div class="hide">
#            <ul class="modelsliderrecent">
#            </ul>
#           </div>
#           <div class="">
#            <ul class="modelslidershort">
#            </ul>
#           </div>
#          </div>
#          <div class="shortlistFixedBtn hidden-xs hidden-sm">
#          </div>
#         </section>
#        </div>
#       </main>
#       <button class="hide" data-popup="usedcar-detailpopup" id="usedcar-detailpopup-btn">
#        Open Thank you popup
#       </button>
#       <div class="UsedDetailPopupOuter hide" id="PopStick">
#        <div class="gsc_modal gsc_modalWindow detailpopup" data-popup-box="usedcar-detailpopup">
#         <div class="gsc_modalWrapper">
#          <div class="gsc_closeBtn" id="gsp_detail_model" title="Close">
#           ×
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="footer_Start">
#      <div>
#      </div>
#     </div>
#     <div>
#      <div class="hashPopup">
#       <div class="ReactTypeahead inputfield gs_ta hide" data-gsmtl-container="true">
#        <input aria-label="Select City" autocomplete="new-password" class="" data-gsf-name="cityName1" data-gsv-min-length="50" data-gsv-type="required" data-id="cityName1" data-move-top="0" data-type="cityName1" id="cityName1" maxlength="50" name="cityName1a6475f52e51ca" type="text" value=""/>
#        <label class=" " for="cityName1">
#         Change City
#        </label>
#       </div>
#       <div class="hide" id="cityPopUp">
#        <span class="gsc_overlay1 open">
#        </span>
#        <div class="gsc_modal gsc_modalWindow gsc_container show" data-popup-box="SelectCity">
#         <span class="gsc_closeBtn">
#          ×
#         </span>
#         <div class="gsc_col-sm-12">
#          <div class="popdis">
#           Which is your city ?
#          </div>
#         </div>
#         <div class="gsc_col-sm-12">
#          <form autocomplete="off" data-cityform="true" data-gsmtl-container="true" id="SelectCity">
#           <div class="inputfield gs_ta">
#            <div class="ReactTypeahead inputfield gs_ta " data-gsmtl-container="true">
#             <input aria-label="Select City" autocomplete="new-password" class="" data-gsf-name="cityName" data-gsv-min-length="50" data-gsv-type="required" data-id="cityName" data-move-top="0" data-type="cityName" id="cityName" maxlength="50" name="cityName1cecbd1d85ce9" type="text" value=""/>
#             <label class="activeTop " for="cityName">
#              Type your city, e.g. Jaipur, New Delhi
#             </label>
#            </div>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#       <div class="gsc_modal gsc_overlay" data-popup-overlay="true">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    window.__INITIAL_STATE__ = {"seo":{"title":"Used Maruti Celerio in Delhi NCR - 42 Second Hand Cars for Sale (with Offers!)","metaDescription":"24 Jun 2019 - Currently, 42 Used Maruti Celerio in Delhi NCR are available for sale online. Check out the largest stock of certified, good condition Second Hand Maruti Celerio Cars in all over Delhi NCR, starting at Rs 3.16 Lakh only.","heading":"Used Maruti Celerio in Delhi NCR","ogImage":"https://stimg.cardekho.com/images/logo/cardekho_logo.jpg","amp":true,"path":"/used-maruti-celerio+cars+in+delhi-ncr","screen":"UsedCar","type":"website"},"popularModels":{},"quickfilters":[],"specsHeading":[],"specsClass":"","research":"","widget":"","usedCarCity":"Delhi NCR","cid":"49","currenturl":"used-maruti-celerio+cars+in+delhi-ncr","cookieCityId":"49","cookieCityName":"Delhi NCR","items":[{"loc":"Gurgaon","myear":"2015","bt":"Hatchback","ft":"CNG","km":"64,687","it":0,"pi":"https://images10.gaadicdn.com/usedcar_image/320x240/usedcar_ttttttttttttt_93781558160086_1558160289.jpg","images":[{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_ttttttttttttt_93781558160086_1558160289.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_ttttttttttttt_93781558160086_1558160289.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_file_93781558160086_1558160274.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_file_93781558160086_1558160274.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_xdxc_93781558160086_1558160303.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_xdxc_93781558160086_1558160303.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_yyyyyyyyyyy_93781558160086_1558160297.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_yyyyyyyyyyy_93781558160086_1558160297.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_gg_93781558160086_1558160351.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_gg_93781558160086_1558160351.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_iii_93781558160086_1558160276.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_iii_93781558160086_1558160276.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_tyyyyyyyyyy_93781558160086_1558160279.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_tyyyyyyyyyy_93781558160086_1558160279.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_ygy_93781558160086_1558160282.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_ygy_93781558160086_1558160282.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_yyy_93781558160086_1558160286.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_yyy_93781558160086_1558160286.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_tyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy_93781558160086_1558160292.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_tyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy_93781558160086_1558160292.webp"},{"img":"https://images10.gaadicdn.com/usedcar_image/gallery/usedcar_tyyyyyyyyyyyy_93781558160086_1558160294.jpg","webp":"https://images10.gaadicdn.com/usedcar_image/gallerywebp/2019/usedcar_tyyyyyyyyyyyy_93781558160086_1558160294.webp"}],"pn":"5.87 Lakh","pu":"3.8 Lakh","dvn":"Maruti Celerio CNG VXI MT","ic":11,"ucid":2322346,"sid":"2104967","ip":"1","oem":"Maruti","model":"Maruti Celerio","vid":"Maruti Celerio CNG VXI MT","city":"Gurgaon","vlink":"/used-car-details/used-Maruti-Celerio-CNG-VXI-MT-cars-Gurgaon_A4DD17E617CBC3F8CD796BD4D3409D97.htm","p_numeric":380000,"webp_image":"https://images10.gaadicdn.com/usedcar_image/320x240webp/2019/usedcar_ttttttttttttt_937815581600 ...
#   </script>
#   <script>
#    window.addEventListener('load', buildScriptTag);function buildScriptTag() {var script = document.createElement('script');script.src ="https://staticcont.cardekho.com/pwa/js/lib/react-16-8.min.js";script.async = false;document.body.appendChild(script);var script = document.createElement('script');script.src ="https://staticcont.cardekho.com/pwa/js/lib/react-16-8-dom.min.js";script.async = false;document.body.appendChild(script);var script = document.createElement('script');script.src = "https://staticcont.cardekho.com/pwa/js/bundle/common.d189af340502b1369185.js";script.async = false;document.body.appendChild(script);var script = document.createElement('script');script.src = "https://staticcont.cardekho.com/pwa/js/bundle/UsedCarListing.2fc3969883d791484e00.js";script.async = false;document.body.appendChild(script);var script = document.createElement('script');script.src ="https://staticcont.cardekho.com/pwa/js/bundle/bundle.ca2c7e98a9ad0ca269ff.js";script.async = false;document.body.appendChild(script);}
#   </script>
#  </body>
# </html>

# %%
carsList = []
# carsList.append(['sno', 'title', 'price', 'location', 'milage', 'fule_type', 'city'])
sno = 0
for i in soup.findAll("div", {"class": "holder"}):
    sno += 1
    title = i.find("div", {"class": "title"}).find('a').text
    price = i.find("div", {"class": "price"}).text
    location = ""
    if i.find("span", {"class": "truncate"}):
        location = i.find("span", {"class": "truncate"}).text
    milage = i.find("div", {"class": "dotlist"}).findAll('span')[0].text
    fule_type = i.find("div", {"class": "dotlist"}).findAll('span')[1].text
    city = i.find("div", {"class": "dotlist"}).findAll('span')[2].text
    mycar = [sno, title, price, location, milage, fule_type, city]
    carsList.append(mycar)

#     print('\n')
   
print(carsList)
# Out:
# [[1, '2015 Maruti Celerio CNG VXI MT', 'Rs.3.8 Lakh', 'Gurgaon', '64,687 km', 'CNG', 'Gurgaon'], [2, '2018 Maruti Celerio VXI MT', 'Rs.4.95 Lakh', 'Sector 10', '12,319 km', 'Petrol', 'Noida'], [3, '2014 Maruti Celerio ZXI', 'Rs.3.7 Lakh', 'Sector 10', '52,000 km', 'Petrol', 'Noida'], [4, '2014 Maruti Celerio VXI', 'Rs.3.2 Lakh', 'Lajpat Nagar', '48,300 km', 'Petrol', 'New Delhi'], [5, '2015 Maruti Celerio VXI AT', 'Rs.3.9 Lakh', 'Faridabad', '27,000 km', 'Petrol', 'Faridabad'], [6, '2016 Maruti Celerio ZXI AT', 'Rs.3.72 Lakh', 'Mathura Road Faridabad', '67,267 km', 'Petrol', 'Faridabad'], [7, '2014 Maruti Celerio VXI AT', 'Rs.3.5 Lakh', 'Lajpat Nagar', '40,000 km', 'Petrol', 'New Delhi'], [8, '2014 Maruti Celerio VXI AT', 'Rs.3.16 Lakh', 'Vasant Kunj', '62,154 km', 'Petrol', 'New Delhi'], [9, '2016 Maruti Celerio ZXI MT', 'Rs.4.2 Lakh', 'Sector 18', '46,136 km', 'Petrol', 'Noida'], [10, '2016 Maruti Celerio VXI MT', 'Rs.3.6 Lakh', 'Kirti nagar', '9,974 km', 'Petrol', 'New Delhi'], [11, '2016 Maruti Celerio VXI', 'Rs.4.5 Lakh', 'Sector 10', '2,400 km', 'Petrol', 'Noida'], [12, '2014 Maruti Celerio VXI', 'Rs.3.25 Lakh', 'Lajpat Nagar', '48,000 km', 'Petrol', 'New Delhi'], [13, '2017 Maruti Celerio ZXI AMT', 'Rs.4.75 Lakh', 'Sector 18', '32,825 km', 'Petrol', 'Noida'], [14, '2017 Maruti Celerio VXI AT', 'Rs.4.5 Lakh', 'Sector 10', '31,000 km', 'Petrol', 'Noida'], [15, '2015 Maruti Celerio ZDi Option', 'Rs.3.35 Lakh', 'Noida', '40,700 km', 'Diesel', 'Noida'], [16, '2016 Maruti Celerio ZXI AT', 'Rs.4.25 Lakh', 'Rohini Sector 25', '16,000 km', 'Petrol', 'New Delhi'], [17, '2017 Maruti Celerio ZXI AMT', 'Rs.4.5 Lakh', 'Sector 28', '20,695 km', 'Petrol', 'Gurgaon'], [18, '2017 Maruti Celerio ZXI AMT', 'Rs.4.6 Lakh', 'Sector 28', '36,129 km', 'Petrol', 'Gurgaon'], [19, '2015 Maruti Celerio VDi', 'Rs.3.5 Lakh', 'Naraina', '40,000 km', 'Diesel', 'New Delhi'], [20, '2014 Maruti Celerio VXI AT', 'Rs.3.25 Lakh', 'Bengali Market', '48,000 km', 'Petrol', 'New Delhi']]

# %%
df = pd.DataFrame(carsList, columns=['sno', 'title', 'price', 'location', 'milage', 'fule_type', 'city'])
df.to_csv('carlist.csv', index=False)
