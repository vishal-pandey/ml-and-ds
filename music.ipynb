# %%
from pydub import AudioSegment

# %%
song = AudioSegment.from_mp3("music1.mp3")

# %%
ten_seconds = 10 * 1000

# %%
new_song = song[0:1000]
for e in range(int(song.duration_seconds)):
    if e%2==0:
        new_song += song[e*1000:((e+1)*1000)]

# %%
new_song
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
new_song.reverse()
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
a = AudioSegment.from_wav('sounds/a.wav')
b = AudioSegment.from_wav('sounds/b.wav')
c = AudioSegment.from_wav('sounds/c.wav')
d = AudioSegment.from_wav('sounds/d.wav')
e = AudioSegment.from_wav('sounds/e.wav')
f = AudioSegment.from_wav('sounds/f.wav')
g = AudioSegment.from_wav('sounds/g.wav')

# %%
c[:500]+c[:600]+g[:500]+g[:500]+a[:700]+a[:500]+g[:300]+f[:400]+f[:500]+d[:500]+d[:700]+e[:500]+e[:600]+c[:70]
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
a
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
a-10
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
a.dBFS
# Out:
# -14.740185027769702

# %%
b.dBFS
# Out:
# -14.163711593672215

# %%
a.channels
# Out:
# 2

# %%
a.sample_width
# Out:
# 2

# %%
a.frame_rate
# Out:
# 44100

# %%
a.rms
# Out:
# 6004

# %%
a.max
# Out:
# 32768

# %%
a.max_dBFS
# Out:
# 0.0

# %%
a.duration_seconds
# Out:
# 1.540498866213152

# %%
b.overlay(e-10)
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
a.fade_out(1000)
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
xx = a.split_to_mono()

# %%
xx[0]
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
xx[1]
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
a.invert_phase()
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
