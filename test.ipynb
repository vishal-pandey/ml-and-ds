# %%
import pandas as pd

# %%
import numpy as np

# %%
x = []
def myFunc():
    for i in range(1000000):
        x.append(np.random.randint(100))

# %%
# %time myFunc()
# Out:
# CPU times: user 2.85 s, sys: 9.36 ms, total: 2.86 s
# Wall time: 2.85 s

# %%
# %time x.sort()
# Out:
# CPU times: user 130 ms, sys: 10.7 ms, total: 141 ms
# Wall time: 140 ms

# %%
x
# Out:
# [55663492416574,
#  70083396501072,
#  278874487423412,
#  334885649424430,
#  379313172648034,
#  409457147694792,
#  446644889731667,
#  457498698124713,
#  498958839904447,
#  503488096936853,
#  519065368495759,
#  539595942262658,
#  619635812545527,
#  665916260871433,
#  700088135676575,
#  704129109547759,
#  747292172291081,
#  796143531401696,
#  796775590753780,
#  940519489613994,
#  1000713802076976,
#  1220817768256276,
#  1222892797685394,
#  1277522678841914,
#  1277799923364174,
#  1296771615461727,
#  1343961953018251,
#  1525745398842027,
#  1718679568224130,
#  2419062586717480,
#  2422390360266973,
#  2450174285715442,
#  2533325385920147,
#  2533874826705995,
#  2584657094326692,
#  2632660901814547,
#  2643735322088606,
#  2763242218838592,
#  3478573208858215,
#  3535006928311880,
#  3750077723100997,
#  3855694821295705,
#  4075557176733933,
#  4093521612334111,
#  4305023570154958,
#  4436216046495806,
#  4565876473426363,
#  4617581123671804,
# ...
